# %%
import pycountry
langs = [(l.alpha_2 or l.alpha_3, l.name) for l in pycountry.languages if getattr(l, "name", None)]
print(langs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/ty/z38pt4mn1fqg3_x_2b5zfnt80000gn/T/ipykernel_40245/2457085184.py in <module>
# ----> 1 import pycountry
#       2 langs = [(l.alpha_2 or l.alpha_3, l.name) for l in pycountry.languages if getattr(l, "name", None)]
#       3 print(langs)
#
# ModuleNotFoundError: No module named 'pycountry'
