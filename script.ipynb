# %%
from sample_data import sample
import json
print(json.dumps(sample, indent=2, sort_keys=True, ensure_ascii=False))
# Out:
# {
#   "ephemeral_pubkey": "a85e129f49e1995fe6b4b8c892bd88505d3301a3e3d6ad7febf92a6ed9d5361a",
#   "fragment_type": "IDENTITY",
#   "hint": "i read book lol",
#   "languages": [
#     "ENGLISH"
#   ],
#   "match_threshold": 0.85,
#   "protocol_version": "2026-03-21",
#   "region": [
#     "us",
#     "japan"
#   ],
#   "social_apps": [
#     "WHATSAPP"
#   ],
#   "vector": [
#     0.3419521607613537,
#     0.27301822577126156,
#     0.6661823063322561,
#     0.5486302531621893,
#     0.1479707888875662,
#     0.9277753055548534,
#     0.6104204101639484,
#     0.4744860975510625,
#     0.2691306260257663,
#     0.7392884556446315,
#     0.6846365373658823,
#     0.7146274590563196,
#     0.215314494421463,
#     0.9261919277299662,
#     0.9458268026664158,
#     0.5559333610713313,
#     0.619619259552106,
#     0.29151310606888137,
#     0.4961545393374296,
#     0.6024682554394465,
#     0.035642518395612166,
#     0.9396596545172317,
#     0.9160511989488521,
# ...
